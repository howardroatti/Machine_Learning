# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/cluster/plot_inductive_clustering.html
# <br>
# https://stackabuse.com/hierarchical-clustering-with-python-and-scikit-learn/

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
import bs4
import requests
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AgglomerativeClustering
from sklearn.ensemble import RandomForestClassifier
from sklearn.base import BaseEstimator, clone
from sklearn.utils.metaestimators import if_delegate_has_method
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
class InductiveClusterer(BaseEstimator):
    def __init__(self, clusterer, classifier):
        self.clusterer = clusterer
        self.classifier = classifier

    def fit(self, X, y=None):
        self.clusterer_ = clone(self.clusterer)
        self.classifier_ = clone(self.classifier)
        y = self.clusterer_.fit_predict(X)
        self.classifier_.fit(X, y)
        return self

    @if_delegate_has_method(delegate='classifier_')
    def predict(self, X):
        return self.classifier_.predict(X)

    @if_delegate_has_method(delegate='classifier_')
    def decision_function(self, X):
        return self.classifier_.decision_function(X)

# %%
def obtain_parse_wiki_snp500(): 
    """ Download and parse the Wikipedia list of S&P500 constituents using requests and Beautiful Soup.
    """     
    
    response = requests.get( "http://en.wikipedia.org/wiki/List_of_S%26P_500_companies" )
    
    soup = bs4.BeautifulSoup(response.text)
    
    # This selects the first table, using CSS Selector syntax and then ignores the header row ([1:])
    symbolslist = soup.select('table')[0].select('tr')[1:]
    
    # Obtain the symbol information for each row in the S&P500 constituent table
    symbols = []
    for i, symbol in enumerate(symbolslist):
        tds = symbol.select('td')
        symbols.append((#tds[0].select('a')[0].text, # Ticker
                        tds[1].select('a')[0].text, # Name
                        tds[3].text, # Sector
                        tds[4].text # SubSector
                      )) 
 
    return symbols
 
tickers = obtain_parse_wiki_snp500()

# %%
documents = [' '.join([word for word in row]) for row in tickers]

# %%
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

# %%
#linkage  -> ward, complete, average, single
#affinity -> euclidean, l1, l2, manhattan, cosine
clusterer = AgglomerativeClustering(n_clusters=11, affinity='euclidean', linkage='ward')
clusterer.fit(X.toarray())
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward', memory=None, n_clusters=11,
#             pooling_func=<function mean at 0x000002A047D71950>)

# %%
# Declare the inductive learning model that it will be used to
# predict cluster membership for unknown instances
classifier = RandomForestClassifier()
inductive_learner = InductiveClusterer(clusterer, classifier).fit(X.toarray())

print("\n")
print("Prediction")

Y = vectorizer.transform(["PicPay Financials Financial Exchanges & Data"])
prediction = inductive_learner.predict(Y.toarray())
print(prediction)

Y = vectorizer.transform(["Vale Industrials Industrial Conglomerates"])
prediction = inductive_learner.predict(Y.toarray())
print(prediction)
# Out:
# Prediction
# [2]
# [3]

# %%
for i in range(11):
    term = "===Cluster %d===" % i
    print(term.replace(term, "\033[48;5;0m\033[38;5;226m {term} \033[0;0m".format(term=term)))
    for j in range(len(documents)):
        if clusterer.labels_[j] == i:
            print(clusterer.labels_[j], ' ', tickers[j][0], '\t\t', tickers[j][1])
# Out:
#  ===Cluster 0===
# 0   Accenture 		 Information Technology
# 0   Adobe Inc. 		 Information Technology
# 0   Advanced Micro Devices 		 Information Technology
# 0   Akamai Technologies 		 Information Technology
# 0   Amphenol Corp 		 Information Technology
# 0   Analog Devices, Inc. 		 Information Technology
# 0   ANSYS, Inc. 		 Information Technology
# 6   Home Depot 		 Consumer Discretionary
# 6   L Brands Inc. 		 Consumer Discretionary
# 6   Las Vegas Sands 		 Consumer Discretionary
# 6   Leggett & Platt 		 Consumer Discretionary
# 6   Lennar Corp. 		 Consumer Discretionary
# 6   LKQ Corporation 		 Consumer Discretionary
# 6   Lowe's Cos. 		 Consumer Discretionary
# 6   Marriott International 		 Consumer Discretionary
# 6   McDonald's Corp. 		 Consumer Discretionary
# 6   MGM Resorts International 		 Consumer Discretionary
# 6   Mohawk Industries 		 Consumer Discretionary
# 6   Newell Brands 		 Consumer Discretionary
# 6   Nike, Inc. 		 Consumer Discretionary
# 6   Norwegian Cruise Line Holdings 		 Consumer Discretionary
# 6   NVR, Inc. 		 Consumer Discretionary
# 6   O'Reilly Automotive 		 Consumer Discretionary
# 6   Penn National Gaming 		 Consumer Discretionary
# 6   Pool Corporation 		 Consumer Discretionary
# 6   PulteGroup 		 Consumer Discretionary
# 6   PVH Corp. 		 Consumer Discretionary
# 6   Ralph Lauren Corporation 		 Consumer Discretionary
# 6   Ross Stores 		 Consumer Discretionary
# 6   Royal Caribbean Group 		 Consumer Discretionary
# 6   Starbucks Corp. 		 Consumer Discretionary
# 6   Tapestry, Inc. 		 Consumer Discretionary
# 6   Target Corp. 		 Consumer Discretionary
# 6   Tesla, Inc. 		 Consumer Discretionary
# 6   TJX Companies Inc. 		 Consumer Discretionary
# 6   Tractor Supply Company 		 Consumer Discretionary
# 6   Ulta Beauty 		 Consumer Discretionary
# 6   Under Armour 		 Consumer Discretionary
# 6   Under Armour 		 Consumer Discretionary
# 6   VF Corporation 		 Consumer Discretionary
# 6   Whirlpool Corp. 		 Consumer Discretionary
# 6   Wynn Resorts Ltd 		 Consumer Discretionary
# 6   Yum! Brands Inc 		 Consumer Discretionary
#  ===Cluster 7===
# 7   APA Corporation 		 Energy
# 7   Baker Hughes Co 		 Energy
# 7   Cabot Oil & Gas 		 Energy
# 7   Chevron Corp. 		 Energy
# 7   ConocoPhillips 		 Energy
# 7   Devon Energy 		 Energy
# 7   Diamondback Energy 		 Energy
# 7   EOG Resources 		 Energy
# 7   Exxon Mobil Corp. 		 Energy
# 7   Halliburton Co. 		 Energy
# 7   Hess Corporation 		 Energy
# 7   HollyFrontier Corp 		 Energy
# 7   Kinder Morgan 		 Energy
# 7   Marathon Oil Corp. 		 Energy
# 7   Marathon Petroleum 		 Energy
# 7   NOV Inc. 		 Energy
# 7   Occidental Petroleum 		 Energy
# 7   Oneok 		 Energy
# 7   Phillips 66 		 Energy
# 7   Pioneer Natural Resources 		 Energy
# 7   Schlumberger Ltd. 		 Energy
# 7   Valero Energy 		 Energy
# 7   Williams Companies 		 Energy
#  ===Cluster 8===
# 8   Activision Blizzard 		 Communication Services
# 8   Alphabet Inc. 		 Communication Services
# 8   Alphabet Inc. 		 Communication Services
# 8   AT&T Inc. 		 Communication Services
# 8   Charter Communications 		 Communication Services
# 8   Comcast Corp. 		 Communication Services
# 8   Discovery, Inc. 		 Communication Services
# 8   Discovery, Inc. 		 Communication Services
# 8   Dish Network 		 Communication Services
# 8   Electronic Arts 		 Communication Services
# 8   Facebook, Inc. 		 Communication Services
# 8   Fox Corporation 		 Communication Services
# 8   Fox Corporation 		 Communication Services
# 8   Interpublic Group 		 Communication Services
# 8   Live Nation Entertainment 		 Communication Services
# 8   Lumen Technologies 		 Communication Services
# 8   Netflix Inc. 		 Communication Services
# 8   News Corp 		 Communication Services
# 8   News Corp 		 Communication Services
# 8   Omnicom Group 		 Communication Services
# 8   T-Mobile US 		 Communication Services
# 8   Take-Two Interactive 		 Communication Services
# 8   Twitter, Inc. 		 Communication Services
# 8   Verizon Communications 		 Communication Services
#
# 8   ViacomCBS 		 Communication Services
# 8   The Walt Disney Company 		 Communication Services
#  ===Cluster 9===
# 9   AES Corp 		 Utilities
# 9   Alliant Energy 		 Utilities
# 9   Ameren Corp 		 Utilities
# 9   American Electric Power 		 Utilities
# 9   American Water Works 		 Utilities
# 9   Atmos Energy 		 Utilities
# 9   CenterPoint Energy 		 Utilities
# 9   CMS Energy 		 Utilities
# 9   Consolidated Edison 		 Utilities
# 9   Dominion Energy 		 Utilities
# 9   DTE Energy Co. 		 Utilities
# 9   Duke Energy 		 Utilities
# 9   Edison Int'l 		 Utilities
# 9   Entergy Corp. 		 Utilities
# 9   Evergy 		 Utilities
# 9   Eversource Energy 		 Utilities
# 9   Exelon Corp. 		 Utilities
# 9   FirstEnergy Corp 		 Utilities
# 9   NextEra Energy 		 Utilities
# 9   NiSource Inc. 		 Utilities
# 9   NRG Energy 		 Utilities
# 9   Pinnacle West Capital 		 Utilities
# 9   PPL Corp. 		 Utilities
# 9   Public Service Enterprise Group (PSEG) 		 Utilities
# 9   Sempra Energy 		 Utilities
# 9   Southern Company 		 Utilities
# 9   WEC Energy Group 		 Utilities
# 9   Xcel Energy Inc 		 Utilities
#  ===Cluster 10===
# 10   Air Products & Chemicals 		 Materials
# 10   Albemarle Corporation 		 Materials
# 10   Amcor plc 		 Materials
# 10   Avery Dennison Corp 		 Materials
# 10   Ball Corp 		 Materials
# 10   Celanese 		 Materials
# 10   CF Industries Holdings Inc 		 Materials
# 10   Corteva 		 Materials
# 10   Dow Inc. 		 Materials
# 10   DuPont de Nemours Inc 		 Materials
# 10   Eastman Chemical 		 Materials
# 10   Ecolab Inc. 		 Materials
# 10   FMC Corporation 		 Materials
# 10   Freeport-McMoRan Inc. 		 Materials
# 10   International Paper 		 Materials
# 10   International Flavors & Fragrances 		 Materials
# 10   Linde plc 		 Materials
# 10   LyondellBasell 		 Materials
# 10   Martin Marietta Materials 		 Materials
# 10   The Mosaic Company 		 Materials
# 10   Newmont Corporation 		 Materials
# 10   Nucor Corp. 		 Materials
# 10   Packaging Corporation of America 		 Materials
# 10   PPG Industries 		 Materials
# 10   Sealed Air 		 Materials
# 10   Sherwin-Williams 		 Materials
# 10   Vulcan Materials 		 Materials
# 10   WestRock 		 Materials
