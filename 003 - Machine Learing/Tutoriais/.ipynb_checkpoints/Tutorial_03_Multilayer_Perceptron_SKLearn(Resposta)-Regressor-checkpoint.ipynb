# %%
import pandas as pd

df_wine = pd.read_csv('winequality-red.csv')
print(df_wine.shape)
df_wine.describe().transpose()
# Out:
# (1599, 12)
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
target_column = ['quality'] 
predictors = list(set(list(df_wine.columns))-set(target_column))
print(predictors)
# Out:
# ['pH', 'alcohol', 'volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide', 'chlorides', 'density', 'sulphates', 'fixed acidity', 'residual sugar', 'citric acid']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

transformer = StandardScaler()
le = LabelEncoder()

df_std = df_wine.copy()

df_std[predictors] = transformer.fit_transform(df_wine[predictors])
df_std[target_column] = le.fit_transform(df_std[target_column])


df_std.describe().transpose()
# Out:
# C:\Users\Howard\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#                        count          mean       std       min       25%  \
# fixed acidity         1599.0  3.554936e-16  1.000313 -2.137045 -0.700719
# volatile acidity      1599.0  1.733031e-16  1.000313 -2.278280 -0.769931
# citric acid           1599.0 -8.887339e-17  1.000313 -1.391472 -0.929318
# residual sugar        1599.0 -1.244227e-16  1.000313 -1.162696 -0.453218
# chlorides             1599.0  3.821556e-16  1.000313 -1.603945 -0.371229
# free sulfur dioxide   1599.0 -6.221137e-17  1.000313 -1.422500 -0.848716
# total sulfur dioxide  1599.0  4.443669e-17  1.000313 -1.230584 -0.744040
# density               1599.0 -3.473172e-14  1.000313 -3.538731 -0.607756
# ...

# %%
from sklearn.model_selection import train_test_split

X_std = df_std[predictors].values
y_std = df_std[target_column].values

X_train_std, X_test_std, y_train_std, y_test_std = train_test_split(X_std, y_std, test_size=0.30, random_state=12)
print(X_train_std.shape,y_train_std.shape)
print(X_test_std.shape,y_test_std.shape)
# Out:
# (1119, 11) (1119, 1)
# (480, 11) (480, 1)

# %%
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
# %matplotlib inline

mlp_std = MLPRegressor(hidden_layer_sizes=(11, 33, 66),
                        activation='relu',
                        solver='adam',
                        max_iter=500,
                        random_state=12                        
                       )
mlp_std.fit(X_train_std, y_train_std)
predict_test_std = mlp_std.predict(X_test_std)
# Out:
# C:\Users\Howard\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Howard\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score, accuracy_score

# The mean squared error
print('Mean squared error: %.2f'
      % mean_absolute_error(y_test_std, predict_test_std))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test_std, predict_test_std))
# Out:
# Mean squared error: 0.50
# Coefficient of determination: 0.20

# %%
# Plot outputs
plt.rcParams["figure.figsize"] = (20,3)
plt.scatter(range(480), y_test_std,  color='blue')
#plt.plot(range(480), predict_test_std, color='black', linewidth=1)
plt.scatter(range(480), predict_test_std, color='red')

plt.xticks(())
plt.yticks(())

plt.show()

# %%
from yellowbrick.regressor import PredictionError

visualizer = PredictionError(mlp_std)
visualizer.fit(X_train_std, y_train_std)# Fit the training data to the visualizer
visualizer.score(X_test_std, y_test_std)# Evaluate the model on the test data
visualizer.show()                       # Finalize and render the figure

# %%
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import LabelEncoder

transformer = Normalizer()
le = LabelEncoder()

df_norm = df_wine.copy()

df_norm[predictors] = transformer.fit_transform(df_wine[predictors])
df_norm[target_column] = le.fit_transform(df_norm[target_column])

df_norm.describe().transpose()
# Out:
# C:\Users\Howard\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#                        count      mean       std       min       25%  \
# fixed acidity         1599.0  0.219976  0.129545  0.027062  0.114584
# volatile acidity      1599.0  0.013716  0.009362  0.001028  0.007091
# citric acid           1599.0  0.007081  0.007231  0.000000  0.001912
# residual sugar        1599.0  0.063927  0.045598  0.007771  0.033655
# chlorides             1599.0  0.002256  0.001676  0.000112  0.001162
# free sulfur dioxide   1599.0  0.309385  0.114849  0.021791  0.221418
# total sulfur dioxide  1599.0  0.833325  0.119993  0.337742  0.771839
# density               1599.0  0.026090  0.013876  0.003402  0.014574
# pH                    1599.0  0.086685  0.046292  0.010311  0.048717
# ...

# %%
from sklearn.model_selection import train_test_split

X_norm = df_norm[predictors].values
y_norm = df_norm[target_column].values

X_train_norm, X_test_norm, y_train_norm, y_test_norm = train_test_split(X_norm, y_norm, test_size=0.30, random_state=12)
print(X_train_norm.shape)
print(X_test_norm.shape)
# Out:
# (1119, 11)
# (480, 11)

# %%
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
# %matplotlib inline

mlp_norm = MLPRegressor(hidden_layer_sizes=(11, 33, 11),
                        activation='relu',
                        solver='adam',
                        max_iter=500,
                        random_state=12                        
                       )

mlp_norm.fit(X_train_norm, y_train_norm)
predict_test_norm = mlp_norm.predict(X_test_norm)
# Out:
# C:\Users\Howard\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# The mean squared error
print('Mean squared error: %.2f'
      % mean_absolute_error(y_test_norm, predict_test_norm))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test_norm, predict_test_norm))
# Out:
# Mean squared error: 0.52
# Coefficient of determination: 0.27

# %%
# Plot outputs
plt.rcParams["figure.figsize"] = (20,3)
plt.scatter(range(480), y_test_norm,  color='black')
plt.plot(range(480), predict_test_norm, color='blue', linewidth=1)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
from yellowbrick.regressor import PredictionError

visualizer = PredictionError(mlp_norm)
visualizer.fit(X_train_norm, y_train_norm)# Fit the training data to the visualizer
visualizer.score(X_test_norm, y_test_norm)# Evaluate the model on the test data
visualizer.show()                       # Finalize and render the figure
